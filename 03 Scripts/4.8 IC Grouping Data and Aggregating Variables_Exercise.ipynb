# %% [markdown]
# ## 4.8 Grouping Data and Aggregating Variables

# %% [markdown]
# ### This script contains the following points:
#
# #### 1. Import Data
# #### 2. Create subset
# #### 3. Grouping Data with groupby()
# #### 4. Aggregating Data with agg()
# #### 5. Aggregating Data with transform()
# #### 6. Deriving Colymns with loc()
#
#
# #### 8. Export new dataframe as pickle file

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 1. Import Data

# %%
#Import Data
path = r'C:\Users\eog87\Desktop\Data Analytics\2. Data Immersion\4. Python Fundamentals for Data Analysts\Instacart Basket Analysis'

# Importing products df
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_derived.pkl'))

# %% [markdown]
# #### 2. Create subset

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                  6                 11
# 1   1977647      138            30                  6                 17
# 2    389851      709             2                  0                 21
# 3    652770      764             1                  3                 13
# 4   1813452      764             3                  4                 17
# 5   1701441      777            16                  1                  7
# 6   1871483      825             3                  2                 14
# 7   1290456      910            12                  3                 10
# 8    369558     1052            10                  1                 20
# 9    589712     1052            15                  1                 12
#
#    days_since_last_order  add_to_cart_order  reordered _merge  \
# 0                    3.0                  5          0   both
# 1                   20.0                  1          1   both
# 2                    6.0                 20          0   both
# 3                    NaN                 10          0   both
# 4                    9.0                 11          1   both
# 5                   26.0                  7          0   both
# 6                   30.0                  2          0   both
# 7                   30.0                  1          0   both
# 8                   19.0                  1          0   both
# 9                   15.0                  2          1   both
#
#          price_range    price_range_loc     busiest_day  busiest_days  \
# 0  Mid-range product  Mid-range product  Regularly busy  Regular Days
# 1  Mid-range product  Mid-range product  Regularly busy  Regular Days
# 2  Mid-range product  Mid-range product     Busiest day  Busiest Days
# 3  Mid-range product  Mid-range product  Regularly busy  Slowest Days
# 4  Mid-range product  Mid-range product      Least busy  Slowest Days
# 5  Mid-range product  Mid-range product  Regularly busy  Busiest Days
# 6  Mid-range product  Mid-range product  Regularly busy  Regular Days
# 7  Mid-range product  Mid-range product  Regularly busy  Slowest Days
# 8  Mid-range product  Mid-range product  Regularly busy  Busiest Days
# 9  Mid-range product  Mid-range product  Regularly busy  Busiest Days
#
#   busiest_period_of_day
# 0           Most orders
# 1        Average orders
# 2        Average orders
# 3           Most orders
# 4        Average orders
# 5        Average orders
# 6           Most orders
# 7           Most orders
# 8        Average orders
# 9           Most orders

# %% [markdown]
# #### 3. Grouping Data

# %%
df.groupby('product_name')

# %% [markdown]
# #### 4. Aggregating Data

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.447411   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.803851   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %% [markdown]
# #### 5. Aggregating Data with transform()

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\eog87\AppData\Local\Temp\ipykernel_22540\1681540670.py:1: FutureWarning: The provided callable <function amax at 0x00000167B93904A0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  order_day_of_week  \
# 0            5.8   3139998      138            28                  6
# 1            5.8   1977647      138            30                  6
# 2            5.8    389851      709             2                  0
# 3            5.8    652770      764             1                  3
# 4            5.8   1813452      764             3                  4
# ...          ...       ...      ...           ...                ...
# 32404854    13.5   1788356   200215             2                  0
# 32404855    13.5   3401313   200377             1                  4
# 32404856    13.5    809510   200873             5                  3
# 32404857    13.5   2359893   200873             9                  3
# 32404858    13.5   2385091   205926            11                  1
#
#           order_hour_of_day  days_since_last_order  add_to_cart_order  \
# 0                        11                    3.0                  5
# 1                        17                   20.0                  1
# 2                        21                    6.0                 20
# 3                        13                    NaN                 10
# 4                        17                    9.0                 11
# ...                     ...                    ...                ...
# 32404854                  9                    5.0                 27
# 32404855                 11                    NaN                  5
# 32404856                  8                   15.0                 12
# 32404857                 15                    5.0                 11
# 32404858                 15                    6.0                 35
#
#           reordered _merge        price_range    price_range_loc  \
# 0                 0   both  Mid-range product  Mid-range product
# 1                 1   both  Mid-range product  Mid-range product
# 2                 0   both  Mid-range product  Mid-range product
# 3                 0   both  Mid-range product  Mid-range product
# 4                 1   both  Mid-range product  Mid-range product
# ...             ...    ...                ...                ...
# 32404854          0   both  Mid-range product  Mid-range product
# 32404855          0   both  Mid-range product  Mid-range product
# 32404856          0   both  Mid-range product  Mid-range product
# 32404857          1   both  Mid-range product  Mid-range product
# 32404858          0   both  Mid-range product  Mid-range product
#
#              busiest_day  busiest_days busiest_period_of_day  max_order
# 0         Regularly busy  Regular Days           Most orders         32
# 1         Regularly busy  Regular Days        Average orders         32
# 2            Busiest day  Busiest Days        Average orders          5
# 3         Regularly busy  Slowest Days           Most orders          3
# 4             Least busy  Slowest Days        Average orders          3
# ...                  ...           ...                   ...        ...
# 32404854     Busiest day  Busiest Days        Average orders          6
# 32404855      Least busy  Slowest Days           Most orders          4
# 32404856  Regularly busy  Slowest Days        Average orders         20
# 32404857  Regularly busy  Slowest Days           Most orders         20
# 32404858  Regularly busy  Busiest Days           Most orders         11
#
# [32404859 rows x 20 columns]

# %%
pd.options.display.max_rows = None

# %% [markdown]
# ###### 6. Deriving columns with loc

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# 20     1540  Regular customer             7
# 21     1540  Regular customer             8
# 22     1540  Regular customer             9
# 23     1540  Regular customer            14
# 24     1540  Regular customer            15
# 25     1540  Regular customer            18
# 26     1540  Regular customer            19
# 27     1540  Regular customer            20
# 28     1540  Regular customer            21
# 29     1540  Regular customer            22
# 30     1540  Regular customer            24
# 31     1540  Regular customer            25
# 32     1540  Regular customer            27
# 33     1540  Regular customer            28
# 34     1598      New customer             1
# 35     1598      New customer             2
# 36     1598      New customer             3
# 37     1647      New customer             1
# 38     1647      New customer             4
# 39     1647      New customer             6
# 40     1647      New customer             8
# 41     1647      New customer             9
# 42     2833      New customer             1
# 43     2850  Regular customer             7
# 44     2857  Regular customer            24
# 45     3010  Regular customer             5
# 46     3029      New customer             1
# 47     3395      New customer             4
# 48     3904      New customer             1
# 49     4006    Loyal customer             2
# 50     4006    Loyal customer             3
# 51     4006    Loyal customer             5
# 52     4006    Loyal customer             9
# 53     4006    Loyal customer            12
# 54     4122  Regular customer            11
# 55     4141      New customer             2
# 56     4343      New customer             1
# 57     4553      New customer             3
# 58     4845  Regular customer             6
# 59     6866      New customer             1

# %% [markdown]
# #### 8. Export new dataframe as pickle file

# %%
# Export data to pkl
